# %% [markdown]
# ## Remove - Unnecessary Tags - using TF-IDF Approach

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Step 1: Data Access
url = "/Users/abhishekjaiswal/Downloads/combined_movie_genres_tags.csv"
df = pd.read_csv(url)

# Step 2: Data Preprocessing
df['tagsWithName'] = df['tagsWithName'].apply(eval)

# Step 3: Calculate TF-IDF vectors for tags
tag_strings = df['tagsWithName'].apply(lambda x: ' '.join(x))

# Initialize a TF-IDF vectorizer
vectorizer = TfidfVectorizer()
# Fit and transform the tag strings to obtain TF-IDF vectors
tfidf_matrix = vectorizer.fit_transform(tag_strings)

# Step 4: Calculate cosine similarity matrix
cos_sim_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Step 5: Remove tags with low semantic similarity
threshold = 0.2  # Adjust the threshold as needed

# Iterate over the indices where similarity is below threshold and remove tags
for i in range(len(df)):
    for j in range(i + 1, len(df)):  # Avoid comparing the same movie
        if cos_sim_matrix[i, j] < threshold:
            for tag in df['tagsWithName'].iloc[i]:
                if tag in df['tagsWithName'].iloc[j]:
                    df['tagsWithName'].iloc[j].remove(tag)

# Step 6: Data Saving or Further Analysis
print(df.head())

# Save - to a new CSV file
df.to_csv("/Users/abhishekjaiswal/Downloads/cleaned_movie_data.csv", index=False)
# Out:
#    movieID                                              genre  \
# 0        1  ['Adventure', 'Animation', 'Children', 'Comedy...
# 1        2               ['Adventure', 'Children', 'Fantasy']
# 2        3                              ['Comedy', 'Romance']
# 3        4                     ['Comedy', 'Drama', 'Romance']
# 4        5                                         ['Comedy']
#
#                                           tagsWithID  \
# 0  [896, 900, 1925, 10376, 1290, 13, 528, 6675, 1...
# 1  [14371, 742, 488, 2057, 1224, 2732, 13, 10382,...
# 2               [13668, 2724, 3242, 7444, 380, 3196]
# 3                                                 []
# 4                 [2724, 1646, 752, 4946, 4953, 125]
#
#                                         tagsWithName
# 0  [tumeys vhs, witty, want, rousing, almost favo...
# 1  [joe johnston, game, lebbat, jungle, monkey, k...
# 2  [old, grun running, jack lemmon, funniest movi...
# 3                                                 []
# 4  [watched under duress, sequel, sequel fever, c...

# %% [markdown]
# ## Remove -  Tags Below a Frequency Level

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# Step 1: Data Retrieval
cleaned_data = "/Users/abhishekjaiswal/Downloads/cleaned_movie_data.csv"
df1 = pd.read_csv(cleaned_data)

# Step 2: Data Preprocessing
df1['tagsWithName'] = df1['tagsWithName'].apply(eval)

# Step 3: Analysis (Identify unnecessary tags)
all_tags = [tag for sublist in df['tagsWithName'] for tag in sublist]
tag_freq = pd.Series(all_tags).value_counts()

# Step 4: Filtering (Remove unnecessary tags)
unnecessary_tags = tag_freq[tag_freq < 10].index

def filter_tags(tag_list):
    return [tag for tag in tag_list if tag not in unnecessary_tags]

df1['tagsWithName'] = df1['tagsWithName'].apply(filter_tags)

# Step 5: Removing [] from tagswithID and tagswithName
df1 = df1[~((df1['tagsWithID'] == '[]') | (df1['tagsWithName'] == '[]'))]

# Step 5: Data Saving or Further Analysis
print(df1.head())

# Save - to a new CSV file
# df1.to_csv("/Users/abhishekjaiswal/Downloads/cleaned_movie_data1.csv", index=False)
# Out:
#    movieID                                              genre  \
# 0        1  ['Adventure', 'Animation', 'Children', 'Comedy...
# 1        2               ['Adventure', 'Children', 'Fantasy']
# 2        3                              ['Comedy', 'Romance']
# 4        5                                         ['Comedy']
# 5        6                    ['Action', 'Crime', 'Thriller']
#
#                                           tagsWithID  \
# 0  [896, 900, 1925, 10376, 1290, 13, 528, 6675, 1...
# 1  [14371, 742, 488, 2057, 1224, 2732, 13, 10382,...
# 2               [13668, 2724, 3242, 7444, 380, 3196]
# 4                 [2724, 1646, 752, 4946, 4953, 125]
# 5  [3008, 675, 13128, 2538, 587, 7052, 6988, 528,...
#
#                                         tagsWithName
# 0  [disney animated feature, animation, disney, w...
# 1                                                 []
# 2                                                 []
# 4                                           [sequel]
# 5                                                 []

# %% [markdown]
# ## Check Spelling - using SpellChecker

# %%
from spellchecker import SpellChecker

# Load your DataFrame
#df2 = pd.read_csv("/Users/abhishekjaiswal/Downloads/your_data.csv")

# Initialize spell checker
spell_checker = SpellChecker()

# Function to correct misspelled words
def correct_spelling(tag):
    corrected_tag = spell_checker.correction(tag)
    if corrected_tag is not None:
        corrected_tag = corrected_tag.lower()  # Convert to lowercase if correction is not None
    return corrected_tag if corrected_tag else tag  # Return original tag if no correction found

# Apply the correction function to each tag
df1['tagsWithName'] = df1['tagsWithName'].apply(lambda x: [correct_spelling(tag) for tag in x])

# Optional: Remove duplicates within each list in 'tagsWithName'
df1['tagsWithName'] = df1['tagsWithName'].apply(lambda x: list(set(x)))

df1.to_csv("/Users/abhishekjaiswal/Downloads/moreAccurate_data.csv", index=False)

# %% [markdown]
# ## Remove - Spaces between Words

# %%
import nltk
from nltk.tokenize import word_tokenize

# Tokenize text into words
def word_segment(text):
    return word_tokenize(str(text))  # Convert to string

# Apply word segmentation to each tag
df1_exploded['tagsWithName'] = df1_exploded['tagsWithName'].apply(word_segment)

# Group by the original index and aggregate the lists back into one
df1_grouped = df1_exploded.groupby(df1_exploded.index).agg(list)

# Now, df1_grouped contains the segmented words in the 'tagsWithName' column
df1_grouped.to_csv("/Users/abhishekjaiswal/Downloads/moreAccurate_data.csv", index=False)

# %% [markdown]
# ## Removing - [ ]

# %%
import csv

# Define the input file path
file_path = '/Users/abhishekjaiswal/Downloads/moreAccurate_data.csv'

# Read data from the CSV file
data = []
with open(file_path, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # Convert string representation of lists to actual lists
        row['genre'] = eval(row['genre'])
        row['tagsWithID'] = eval(row['tagsWithID'])
        row['tagsWithName'] = eval(row['tagsWithName'])
        data.append(row)

# Filter out rows with empty values in tagsWithName
filtered_data = [row for row in data if row['tagsWithName']]


df1_grouped.to_csv("/Users/abhishekjaiswal/Downloads/moreAccurate_data.csv", index=False)
# Out:
# {'movieID': '1', 'genre': ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy'], 'tagsWithID': [896, 900, 1925, 10376, 1290, 13, 528, 6675, 15123, 7705, 25, 672, 5289, 6323, 10420, 819, 10422, 55, 4924, 60, 15170, 15045, 326, 2119, 459, 11344, 465, 11477, 605, 14562, 362, 752, 4339, 501, 4342, 2293, 382], 'tagsWithName': ['dinner', 'animation', 'want to see again', 'disney animated feature']}
# {'movieID': '5', 'genre': ['Comedy'], 'tagsWithID': [2724, 1646, 752, 4946, 4953, 125], 'tagsWithName': ['sequel']}
# {'movieID': '10', 'genre': ['Action', 'Adventure', 'Thriller'], 'tagsWithID': [161, 485, 74, 459, 1515, 110, 6800, 657, 977, 5843, 9015, 9816, 634, 125, 1023], 'tagsWithName': ['murder', 'james bond', 'bond', 'assassin', '007 (series)', 'killer as protagonist']}
# {'movieID': '11', 'genre': ['Comedy', 'Drama', 'Romance'], 'tagsWithID': [6401, 587, 651, 780, 689, 892, 10494], 'tagsWithName': ['seen', 'seen more than once']}
# {'movieID': '12', 'genre': ['Comedy', 'Horror'], 'tagsWithID': [944, 42, 1452, 62], 'tagsWithName': ['gothic', 'vampire', 'mel brooks']}
# {'movieID': '16', 'genre': ['Crime', 'Drama'], 'tagsWithID': [353, 258, 711, 521, 587, 77, 6800, 595, 6324, 310, 214, 8889, 251, 4446], 'tagsWithName': ['nudity (rear)']}
# {'movieID': '17', 'genre': ['Comedy', 'Drama', 'Romance'], 'tagsWithID': [643, 292, 1061, 9926, 1224, 1320, 587, 2158, 2260, 5301, 7669, 2364, 605, 13407], 'tagsWithName': ['svens to see list', 'based on a book']}
# {'movieID': '18', 'genre': ['Comedy', 'Drama', 'Thriller'], 'tagsWithID': [2241, 93, 10422], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '20', 'genre': ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller'], 'tagsWithID': [2938, 2261], 'tagsWithName': ['afternoon section']}
# {'movieID': '22', 'genre': ['Crime', 'Drama', 'Horror', 'Mystery', 'Thriller'], 'tagsWithID': [54], 'tagsWithName': ['serial killer']}
# {'movieID': '23', 'genre': ['Action', 'Crime', 'Thriller'], 'tagsWithID': [6324, 2261], 'tagsWithName': ['afternoon section']}
# {'movieID': '25', 'genre': ['Drama', 'Romance'], 'tagsWithID': [1153, 418, 610, 1159, 8583, 2538, 587, 6635, 4491, 4731, 6669, 1422, 625, 11448, 506, 219, 93], 'tagsWithName': ['oscar (best actor)']}
# {'movieID': '26', 'genre': ['Drama'], 'tagsWithID': [1320, 9002, 9298, 93], 'tagsWithName': ['adapted from:play', 'playwright:shakespeare']}
# {'movieID': '28', 'genre': ['Drama', 'Romance'], 'tagsWithID': [4818, 730, 11619], 'tagsWithName': ['opal']}
# {'movieID': '31', 'genre': ['Drama'], 'tagsWithID': [9762, 1925, 587, 910, 2261], 'tagsWithName': ['afternoon section', 'high school']}
# {'movieID': '36', 'genre': ['Crime', 'Drama'], 'tagsWithID': [14562, 2596, 2600, 172, 8142, 1647, 4112, 10173, 4114, 14511, 213, 633, 762, 7804, 4125, 1023], 'tagsWithName': ['oscar (best actress)']}
# {'movieID': '39', 'genre': ['Comedy', 'Romance'], 'tagsWithID': [1253, 1222, 1224, 1450, 651, 5264, 1680, 14035, 7669, 730, 4666, 892, 605], 'tagsWithName': ['seen more than once']}
# {'movieID': '41', 'genre': ['Drama', 'War'], 'tagsWithID': [1472, 1320, 9002, 9298, 4666, 5151], 'tagsWithName': ['adapted from:play', 'playwright:shakespeare', 'robert downey jr']}
# {'movieID': '43', 'genre': ['Drama'], 'tagsWithID': [93, 5711], 'tagsWithName': ['nudity (topless)']}
# {'movieID':
# {'movieID': '111', 'genre': ['Crime', 'Drama', 'Thriller'], 'tagsWithID': [13186, 644, 7428, 6534, 8583, 6800, 10906, 7455, 1065, 10420, 310, 8887, 7738, 8891, 15165, 1216, 706, 583, 587, 8912, 8917, 605, 6749, 5857, 225, 15073, 4707, 741, 2538, 4083, 9334, 10871, 6518, 1277, 638], 'tagsWithName': ['afi 100 (movie quotes)', 'bfi classic', 'afi 100 (thrills)', 'afi 100']}
# {'movieID': '112', 'genre': ['Action', 'Adventure', 'Comedy', 'Crime'], 'tagsWithID': [4994, 15780, 5156, 6220, 686], 'tagsWithName': ['kung fu', 'martial arts']}
# {'movieID': '114', 'genre': ['Drama'], 'tagsWithID': [398], 'tagsWithName': ['less than 300 ratings']}
# {'movieID': '125', 'genre': ['Comedy'], 'tagsWithID': [1057, 501], 'tagsWithName': ['want to see again']}
# {'movieID': '132', 'genre': ['Thriller'], 'tagsWithID': [595, 603, 1751], 'tagsWithName': ['san francisco']}
# {'movieID': '140', 'genre': ['Drama', 'Romance'], 'tagsWithID': [587, 2261, 1822], 'tagsWithName': ['afternoon section']}
# {'movieID': '141', 'genre': ['Comedy'], 'tagsWithID': [1888, 554, 9298, 15286, 55], 'tagsWithName': ['gay']}
# {'movieID': '153', 'genre': ['Action', 'Adventure', 'Comedy', 'Crime'], 'tagsWithID': [1765, 1641, 9547, 364, 7408, 6323, 5557, 1783, 7736, 1561, 186, 125], 'tagsWithName': ['dc comics', 'adapted from:comic', 'superhero', 'dc', 'alter ego', 'franchise']}
# {'movieID': '156', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [5692, 93, 1174], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '175', 'genre': ['Drama'], 'tagsWithID': [14691, 69, 1136, 12820, 6708, 2422], 'tagsWithName': ['hw drama', 'nudity (full frontal)']}
# {'movieID': '176', 'genre': ['Comedy'], 'tagsWithID': [93, 7871], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '178', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [374, 9298, 54, 9750], 'tagsWithName': ['dark comedy', 'serial killer']}
# {'movieID': '187', 'genre': ['Comedy'], 'tagsWithID': [6713, 9653, 9182], 'tagsWithName': ['hw comedy']}
# {'movieID': '190', 'genre': ['Thriller'], 'tagsWithID': [5512, 515, 6822], 'tagsWithName': ['food']}
# {'movieID': '194', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [706, 766, 629, 10845, 510], 'tagsWithName': ['ensemble cast', 'multiple storylines']}
# {'movieID': '196', 'genre': ['Horror', 'Sci-Fi'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '213', 'genre': ['Drama'], 'tagsWithID': [4578, 6715, 6711], 'tagsWithName': ['ruffian', 'not corv lib']}
# {'movieID': '214', 'genre': ['Drama', 'War'], 'tagsWithID': [609, 737, 1554, 85, 5241], 'tagsWithName': ['criterion']}
# {'movieID': '224', 'genre': ['Comedy', 'Drama', 'Romance'], 'tagsWithID': [1277, 146, 59, 2261], 'tagsWithName': ['afternoon section']}
# {'movieID': '225', 'genre': ['Drama', 'Thriller'], 'tagsWithID': [6176], 'tagsWithName': ['michael crichton']}
# {'movieID': '232', 'genre': ['Comedy', 'Drama', 'Romance'], 'tagsWithID': [9446, 5512, 2295, 5692, 6717], 'tagsWithName': ['food', 'corvallis library']}
# {'movieID': '239', 'genre': ['Animation', 'Children', 'Comedy', 'Romance'], 'tagsWithID': [362, 900], 'tagsWithName': ['dinner', 'disney animated feature']}
# {'movieID': '256', 'genre': ['Comedy', 'Sci-Fi'], 'tagsWithID': [4000, 1186, 15045, 71, 7, 1511, 46, 5556, 4924], 'tagsWithName': ['arnold schwarzenegger']}
# {'movieID': '260', 'genre': ['Action', 'Adventure', 'Sci-Fi'], 'tagsWithID': [6533, 6534, 12551, 4616, 3720, 9482, 651, 12, 781, 1783, 141, 6800, 145, 146, 280, 6810, 9756, 7459, 419, 420, 4646, 6520, 6521, 11050, 1834, 5035, 6324, 9781, 6325, 4408, 8890, 446, 1604, 583, 74, 459, 2941, 1614, 3919, 11344, 13144, 11481, 4699, 605, 2144, 1892, 1382, 6502, 2538, 1260, 366, 238, 496, 13169, 887, 4083, 6515, 10741, 4342, 6774, 125, 6518, 10877, 6526], 'tagsWithName': ['usa film registry', 'war', 'noise in space']}
# {'movieID': '261', 'genre': ['Drama'], 'tagsWithID': [1224, 1107, 1061, 6102], 'tagsWithName': ['based on a book']}
# {'movieID': '265', 'genre': ['Drama', 'Romance'], 'tagsWithID': [1153, 4098, 9446, 5512, 1897, 15149, 5230, 6669, 2513, 4339, 10907], 'tagsWithName': ['food']}
# {'movieID': '272', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [102, 7, 16073, 1868, 143, 2965, 6715], 'tagsWithName': ['not corv lib']}
# {'movieID': '273', 'genre': ['Drama', 'Horror'], 'tagsWithID': [1224, 42, 587], 'tagsWithName': ['gothic']}
# {'movieID': '282', 'genre': ['Drama'], 'tagsWithID': [1136, 3586, 741], 'tagsWithName': ['nudity (full frontal)']}
# {'movieID': '289', 'genre': ['Comedy', 'Romance'], 'tagsWithID': [1472], 'tagsWithName': ['robert downey jr']}
# {'movieID': '299', 'genre': ['Drama'], 'tagsWithID': [1888, 7, 554, 656, 9010, 885], 'tagsWithName': ['gay']}
# {'movieID': '300', 'genre': ['Drama'], 'tagsWithID': [352, 2434, 130, 420, 5289, 587, 8014, 2196, 501, 2390, 10422, 127], 'tagsWithName': ['want to see again']}
# {'movieID': '302', 'genre': ['Drama', 'Romance'], 'tagsWithID': [1176, 1136, 10197, 2239], 'tagsWithName': ['netflix', 'nudity (full frontal)']}
# {'movieID': '305', 'genre': ['Comedy'], 'tagsWithID': [1680, 1553, 1136, 4670], 'tagsWithName': ['robert altman']}
# {'movieID': '315', 'genre': ['Action', 'Drama', 'Thriller'], 'tagsWithID': [595, 93], 'tagsWithName': ['nudity (topless)', 'nudity (rear)']}
# {'movieID': '380', 'genre': ['Action', 'Adventure', 'Comedy', 'Romance', 'Thriller'], 'tagsWithID': [1186, 7, 2185, 74, 651, 2474, 11372, 1515, 396, 752, 1295, 110, 6323, 2731, 55, 16158], 'tagsWithName': ['arnold schwarzenegger']}
# {'movieID': '381', 'genre': ['Drama'], 'tagsWithID': [625, 11249, 1422], 'tagsWithName': ['likeilike top pick']}
# {'movieID': '382', 'genre': ['Drama', 'Horror', 'Romance', 'Thriller'], 'tagsWithID': [42, 1749, 9013, 2261, 605, 1470], 'tagsWithName': ['werewolf', 'afternoon section']}
# {'movieID': '393', 'genre': ['Action', 'Adventure', 'Fantasy'], 'tagsWithID': [7407, 655], 'tagsWithName': ['adapted from:game', 'video game adaptation']}
# {'movieID': '405', 'genre': ['Action', 'Sci-Fi'], 'tagsWithID': [2912, 6323, 1136, 125], 'tagsWithName': ['crappy sequel', 'sequel', 'nudity (full frontal)']}
# {'movieID': '413', 'genre': ['Comedy'], 'tagsWithID': [12197, 6025, 11818, 5236, 1524, 16438, 380, 1759], 'tagsWithName': ['rock and roll']}
# {'movieID': '416', 'genre': ['Western'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '434', 'genre': ['Action', 'Adventure', 'Thriller'], 'tagsWithID': [480, 2593, 10758, 775, 4092], 'tagsWithName': ['clint eastwood']}
# {'movieID': '444', 'genre': ['Comedy', 'Romance'], 'tagsWithID': [2399], 'tagsWithName': ['uma thurman']}
# {'movieID': '461', 'genre': ['Drama', 'Romance'], 'tagsWithID': [375], 'tagsWithName': ['lesbian']}
# {'movieID': '477', 'genre': ['Drama', 'Musical'], 'tagsWithID': [102, 586, 499, 6515, 633, 1532, 1759], 'tagsWithName': ['rock and roll']}
# {'movieID': '488', 'genre': ['Drama'], 'tagsWithID': [4251, 5557], 'tagsWithName': ['alter ego']}
# {'movieID': '497', 'genre': ['Comedy', 'Romance'], 'tagsWithID': [10240, 901, 1320, 9002, 5264, 2162, 9298, 5301, 10422], 'tagsWithName': ['adapted from:play', 'playwright:shakespeare']}
# {'movieID': '507', 'genre': ['Crime', 'Drama', 'Thriller'], 'tagsWithID': [1341, 775], 'tagsWithName': ['clint eastwood']}
# {'movieID': '509', 'genre': ['Drama', 'Romance'], 'tagsWithID': [4098, 892, 4491, 6800, 4251, 41, 565, 965, 328, 1608, 1610, 587, 2512, 213, 352, 11488, 1382, 5865, 2153, 2538, 244, 764, 766], 'tagsWithName': ['oscar (best supporting actress)']}
# {'movieID': '511', 'genre': ['Action', 'Drama'], 'tagsWithID': [8929], 'tagsWithName': ['sport:american football']}
# {'movieID': '517', 'genre': ['Action', 'Drama', 'Mystery'], 'tagsWithID': [6176, 740, 1061, 587, 595, 53, 93, 1023], 'tagsWithName': ['michael crichton']}
# {'movieID': '518', 'genre': ['Comedy'], 'tagsWithID': [6308, 13172], 'tagsWithName': ['literary adaptation']}
# {'movieID': '519', 'genre': ['Crime', 'Sci-Fi', 'Thriller'], 'tagsWithID': [2912, 12, 750, 1525, 4344], 'tagsWithName': ['crappy sequel']}
# {'movieID': '520', 'genre': ['Comedy'], 'tagsWithID': [5413, 1253, 7, 6, 1452, 944, 1457, 55, 3930], 'tagsWithName': ['mel brooks']}
# {'movieID': '521', 'genre': ['Crime', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID':
# {'movieID': '593', 'genre': ['Crime', 'Horror', 'Thriller'], 'tagsWithID': [2948, 1925, 6534, 6533, 137, 521, 651, 11148, 397, 1554, 662, 6806, 10907, 419, 1188, 420, 1065, 42, 6323, 54, 10422, 57, 58, 699, 711, 583, 11723, 15053, 8910, 4690, 213, 8917, 219, 2652, 605, 7776, 611, 741, 6502, 4855, 9070, 9711, 7026, 4083, 6518, 247, 6522, 1915, 1023], 'tagsWithName': ['afi 100 (movie quotes)', 'oscar (best picture)', 'best picture', 'afi 100 (thrills)', 'oscar (best directing)', 'afi 100']}
# {'movieID': '594', 'genre': ['Animation', 'Children', 'Drama', 'Fantasy', 'Musical'], 'tagsWithID': [2144, 896, 900, 14181, 5289, 362, 2955, 9033, 781, 15664, 465, 4946, 4083, 1434, 4954], 'tagsWithName': ['dinner', 'animation', 'disney animated feature']}
# {'movieID': '595', 'genre': ['Animation', 'Children', 'Fantasy', 'Musical', 'Romance'], 'tagsWithID': [900, 10376, 9482, 2955, 651, 4496, 13073, 663, 664, 1434, 1440, 2597, 4521, 5289, 6323, 10422, 2614, 9033, 465, 605, 1502, 4577, 11107, 362, 12016, 11134], 'tagsWithName': ['dinner', 'animation', 'disney animated feature']}
# {'movieID': '596', 'genre': ['Animation', 'Children', 'Fantasy', 'Musical'], 'tagsWithID': [1600, 896, 4065, 900, 14181, 326, 871, 362, 146, 6515, 1719, 413], 'tagsWithName': ['dinner', 'disney animated feature']}
# {'movieID': '598', 'genre': ['Comedy', 'Fantasy'], 'tagsWithID': [4578], 'tagsWithName': ['ruffian']}
# {'movieID': '605', 'genre': ['Drama', 'Romance'], 'tagsWithID': [587, 2261], 'tagsWithName': ['afternoon section']}
# {'movieID': '611', 'genre': ['Action', 'Horror', 'Sci-Fi'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '616', 'genre': ['Animation', 'Children'], 'tagsWithID': [896, 362, 10635], 'tagsWithName': ['disney animated feature']}
# {'movieID': '627', 'genre': ['Drama', 'Thriller'], 'tagsWithID': [6341, 2956, 374, 729, 1023], 'tagsWithName': ['dark comedy']}
# {'movieID': '636', 'genre': ['Drama'], 'tagsWithID': [1224, 54], 'tagsWithName': ['serial killer']}
# {'movieID': '639', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [6713], 'tagsWithName': ['hw comedy']}
# {'movieID': '659', 'genre': ['Crime', 'Drama', 'Thriller'], 'tagsWithID': [6715, 587], 'tagsWithName': ['not corv lib']}
# {'movieID': '661', 'genre': ['Animation', 'Children', 'Fantasy', 'Musical'], 'tagsWithID': [5281, 900, 1061, 1224, 362, 9322, 2474, 11470, 337, 465, 5109, 7929], 'tagsWithName': ['based on a book']}
# {'movieID': '685', 'genre': ['Drama'], 'tagsWithID': [1888, 554, 1579, 692], 'tagsWithName': ['gay']}
# {'movieID': '696', 'genre': ['Drama', 'Thriller'], 'tagsWithID': [1136], 'tagsWithName': ['nudity (full frontal)']}
# {'movieID': '704', 'genre': ['Action', 'Adventure'], 'tagsWithID': [686], 'tagsWithName': ['martial arts']}
# {'movieID': '708', 'genre': ['Comedy', 'Romance'], 'tagsWithID': [4946, 1451, 1222, 2399], 'tagsWithName': ['uma thurman']}
# {'movieID': '709', 'genre': ['Adventure', 'Animation', 'Children', 'Comedy', 'Musical'], 'tagsWithID': [1224, 362, 8927], 'tagsWithName': ['author:charles dickens']}
# {'movieID': '737', 'genre': ['Action', 'Sci-Fi'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '741', 'genre': ['Animation', 'Sci-Fi'], 'tagsWithID': [4481, 740, 1925, 712, 1577, 15689, 4780, 7694, 1758], 'tagsWithName': ['anime']}
# {'movieID': '753', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [2399], 'tagsWithName': ['uma thurman']}
# {'movieID': '766', 'genre': ['Drama'], 'tagsWithID': [14506, 11037, 93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '775', 'genre': ['Horror', 'Mystery'], 'tagsWithID': [6308], 'tagsWithName': ['literary adaptation']}
# {'movieID': '783', 'genre': ['Animation', 'Children', 'Musical'], 'tagsWithID': [900, 9797, 1224, 10376, 362], 'tagsWithName': ['dinner', 'disney animated feature']}
# {'movieID': '786', 'genre': ['Action', 'Drama', 'Thriller'], 'tagsWithID': [1186, 3365, 74, 5098, 6324], 'tagsWithName': ['arnold schwarzenegger']}
# {'movieID': '799', 'genre': ['Comedy', 'Horror', 'Thriller'], 'tagsWithID': [2786, 7907, 555, 80, 4980, 54], 'tagsWithName': ['serial killer']}
# {'movieID': '818', 'genre': ['Comedy'], 'tagsWithID': [125], 'tagsWithName': ['sequel']}
# {'movieID': '831', 'genre': ['Drama'], 'tagsWithID': [554], 'tagsWithName': ['gay']}
# {'movieID': '839', 'genre': ['Action', 'Thriller'], 'tagsWithID': [7408, 42, 125], 'tagsWithName': ['gothic', 'sequel', 'adapted from:comic']}
# {'movieID': '842', 'genre': ['Comedy', 'Horror'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '858', 'genre': ['Crime', 'Drama'], 'tagsWithID': [3844, 1925, 6534, 1287, 4491, 9870, 6800, 2452, 12820, 6298, 1435, 29, 1061, 4521, 2348, 2990, 7726, 304, 6324, 10420, 1974, 8891, 1083, 4925, 319, 706, 1091, 583, 6988, 6221, 10830, 8917, 214, 2136, 2393, 2906, 247, 219, 605, 93, 2144, 7776, 1382, 367, 752, 369, 5105, 4083, 630, 1911, 6518, 1277], 'tagsWithName': ['afi 100 (movie quotes)', 'sweeping', 'oscar (best picture)', 'lavish', 'best picture', 'afi 100 (thrills)', 'afi 100']}
# {'movieID': '864', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '866', 'genre': ['Crime', 'Drama', 'Romance', 'Thriller'], 'tagsWithID': [353, 354, 1093, 1382, 5062, 1023, 41, 554, 2538, 583, 662, 375, 6038, 927, 10907, 2268, 7071], 'tagsWithName': ['lesbian']}
# {'movieID': '867', 'genre': ['Comedy', 'Crime'], 'tagsWithID': [2889], 'tagsWithName': ['cary grant']}
# {'movieID': '869', 'genre': ['Crime'], 'tagsWithID': [1553], 'tagsWithName': ['robert altman']}
# {'movieID': '976', 'genre': ['Romance', 'War'], 'tagsWithID': [1224, 761, 6308], 'tagsWithName': ['oscar (best cinematography)', 'literary adaptation']}
# {'movieID': '982', 'genre': ['Drama'], 'tagsWithID': [6715, 1421], 'tagsWithName': ['not corv lib']}
# {'movieID': '1007', 'genre': ['Children', 'Comedy', 'Western'], 'tagsWithID': [9450, 900], 'tagsWithName': ['disney studios']}
# {'movieID': '1009', 'genre': ['Adventure', 'Children', 'Fantasy'], 'tagsWithID': [9450, 167], 'tagsWithName': ['disney studios']}
# {'movieID': '1010', 'genre': ['Children', 'Comedy'], 'tagsWithID': [900, 583, 1705, 9450, 907], 'tagsWithName': ['disney studios']}
# {'movieID': '1012', 'genre': ['Children', 'Drama'], 'tagsWithID': [7704, 1996, 6748, 605], 'tagsWithName': ['animal:dog']}
# {'movieID': '1014', 'genre': ['Children', 'Comedy', 'Drama'], 'tagsWithID': [9450, 900], 'tagsWithName': ['disney studios']}
# {'movieID': '1016', 'genre': ['Children', 'Comedy'], 'tagsWithID': [7704], 'tagsWithName': ['animal:dog']}
# {'movieID': '1017', 'genre': ['Adventure', 'Children'], 'tagsWithID': [900, 4198, 9450, 752, 1523, 2070, 15672, 7101], 'tagsWithName': ['disney studios']}
# {'movieID': '1021', 'genre': ['Children', 'Comedy'], 'tagsWithID': [113, 2418], 'tagsWithName': ['baseball']}
# {'movieID': '1024', 'genre': ['Animation', 'Children', 'Musical'], 'tagsWithID': [362, 14181], 'tagsWithName': ['disney animated feature']}
# {'movieID': '1025', 'genre': ['Animation', 'Children', 'Fantasy', 'Musical'], 'tagsWithID': [900, 14181, 362, 465, 146, 1980, 605], 'tagsWithName': ['dinner', 'animation', 'disney animated feature']}
# {'movieID': '1028', 'genre': ['Children', 'Comedy', 'Fantasy', 'Musical'], 'tagsWithID': [4000, 9443, 4772, 900, 583, 1224, 9450, 686, 3023, 207, 213, 5143], 'tagsWithName': ['disney studios']}
# {'movieID': '1030', 'genre': ['Adventure', 'Animation', 'Children', 'Musical'], 'tagsWithID': [14562, 900, 10340, 362, 654, 605], 'tagsWithName': ['dinner', 'disney animated feature']}
# {'movieID': '1033', 'genre': ['Animation', 'Children', 'Drama'], 'tagsWithID': [5512, 362], 'tagsWithName': ['food', 'disney animated feature']}
# {'movieID': '1035', 'genre': ['Musical', 'Romance'], 'tagsWithID': [1925, 137, 2955, 651, 14349, 4000, 10489, 4646, 5289, 965, 583, 605, 7776, 237, 887, 752, 4083, 6515, 247, 633, 250, 6526], 'tagsWithName': ['oscar (best picture)', 'world war ii', 'best picture', 'oscar (best directing)', 'afi 100']}
# {'movieID': '1037', 'genre': ['Action', 'Horror', 'Sci-Fi', 'Thriller'], 'tagsWithID': [7474, 93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '1038', 'genre': ['Drama'], 'tagsWithID': [587, 6708], 'tagsWithName': ['hw drama']}
# {'movieID': '1043', 'genre': ['Drama', 'Romance'], 'tagsWithID': [595], 'tagsWithName': ['nudity (rear)']}
# {'movieID': '1051', 'genre': ['Drama'], 'tagsWithID': [14042, 6715], 'tagsWithName': ['not corv lib']}
# {'movieID': '1057', 'genre': ['Comedy', 'Musical', 'Romance'], 'tagsWithID': [651, 61, 1925], 'tagsWithName': ['seen more than once']}
# {'movieID': '1059', 'genre': ['Drama', 'Romance'], 'tagsWithID': [672, 774, 1064, 3081, 74, 1451, 1320, 9002, 5614, 9064, 6800, 369, 9298, 6393, 4666, 415], 'tagsWithName': ['adapted from:play', 'playwright:shakespeare']}
# {'movieID': '1069', 'genre': ['Film-Noir', 'Thriller'], 'tagsWithID': [11936, 2538, 15114, 8941, 6800, 4692, 6715, 6716, 12126, 7071], 'tagsWithName': ['hw classics']}
# {'movieID': '1084', 'genre': ['Crime', 'Drama'], 'tagsWithID': [352, 6150, 102, 6534, 521, 587, 5487, 4083, 244, 3093, 6518, 761, 13052, 605], 'tagsWithName': ['afi 100 (movie quotes)', 'afi 100 (thrills)', 'afi 100']}
# {'movieID': '1086', 'genre': ['Mystery', 'Thriller'], 'tagsWithID': [6534, 9482, 651, 6542, 6800, 15125, 662, 7972, 15147, 6715, 6716, 330, 8910, 605, 1123, 8932, 15077, 5752, 1023], 'tagsWithName': ['alfred hitchcock', 'pinchcock']}
# {'movieID': '1090', 'genre': ['Drama', 'War'], 'tagsWithID': [6534, 137, 8457, 651, 6539, 6800, 6034, 12820, 2462, 4646, 177, 6323, 74, 6219, 7776, 238, 887, 240, 4083, 247, 6526], 'tagsWithName': ['oscar (best picture)', 'war', 'best picture', 'afi 100 (thrills)', 'oscar (best directing)', 'afi 100']}
# {'movieID': '1092', 'genre': ['Mystery', 'Thriller'], 'tagsWithID': [11143, 2153, 3153, 603, 220], 'tagsWithName': ['san francisco']}
# {'movieID': '1099', 'genre': ['Drama'], 'tagsWithID': [497, 9298, 8927], 'tagsWithName': ['author:charles dickens']}
# {'movieID': '1104', 'genre': ['Drama'], 'tagsWithID': [10240, 4707, 6121, 2538, 6126, 2960, 304, 9298, 4083, 244, 213, 11348, 4279, 277, 6518, 9050, 4731, 10907], 'tagsWithName': ['afi 100 (movie quotes)', 'oscar (best supporting actress)', 'afi 100']}
# {'movieID': '1124', 'genre': ['Drama'], 'tagsWithID': [3270, 6515, 213, 6518, 6200, 219, 798], 'tagsWithName': ['afi 100 (movie quotes)']}
# {'movieID': '1130', 'genre': ['Horror', 'Mystery'], 'tagsWithID': [1136, 1803, 1749], 'tagsWithName': ['werewolf', 'nudity (full frontal)']}
# {'movieID': '1147', 'genre': ['Documentary'], 'tagsWithID': [4136, 1426, 3, 6800], 'tagsWithName': ['boxing', 'sport:boxing']}
# {'movieID': '1153', 'genre': ['Film-Noir'], 'tagsWithID': [2927], 'tagsWithName': ['tom']}
# {'movieID': '1161', 'genre': ['Drama', 'War'], 'tagsWithID': [6308, 583, 360, 1065, 396, 1136, 11477], 'tagsWithName': ['nudity (full frontal)']}
# {'movieID': '1168', 'genre': ['Action', 'Adventure', 'Horror'], 'tagsWithID': [1749], 'tagsWithName': ['werewolf']}
# {'movieID': '1171', 'genre': ['Comedy'], 'tagsWithID': [4612, 501], 'tagsWithName': ['want to see again']}
# {'movieID': '1276', 'genre': ['Drama'], 'tagsWithID': [352, 4707, 8932, 7782, 2538, 172, 2960, 6800, 6515, 10997, 10390, 6518, 473, 605], 'tagsWithName': ['afi 100 (movie quotes)']}
# {'movieID': '1278', 'genre': ['Action', 'Comedy', 'Horror'], 'tagsWithID': [867, 4772, 5413, 1925, 3783, 42, 1452, 5423, 5487, 944, 210, 1457, 1524, 1140, 4082, 5466, 2717], 'tagsWithName': ['mel brooks']}
# {'movieID': '1282', 'genre': ['Animation', 'Children', 'Fantasy', 'Musical'], 'tagsWithID': [64, 192, 257, 1091, 900, 5289, 362, 651, 752, 465, 4083, 10422, 887, 605], 'tagsWithName': ['dinner', 'animation', 'disney animated feature']}
# {'movieID': '1283', 'genre': ['Western'], 'tagsWithID': [6534, 9482, 781, 3988, 1944, 4121, 3614, 9507, 2596, 1974, 9533, 5837, 219, 605, 7654, 2928, 2929, 4083, 6515, 634, 1023], 'tagsWithName': ['usa film registry']}
# {'movieID': '1287', 'genre': ['Action', 'Adventure', 'Drama', 'Romance'], 'tagsWithID': [6534, 137, 2960, 6800, 662, 1435, 4521, 5556, 583, 7753, 11344, 4690, 219, 7776, 9579, 887, 4083, 6515, 11382, 247, 761, 7675], 'tagsWithName': ['sword and sandal', 'sweeping', 'oscar (best picture)', 'lavish', 'best picture', 'classical studies', 'oscar (best cinematography)', 'afi 100 (thrills)', 'oscar (best directing)', 'afi 100']}
# {'movieID': '1288', 'genre': ['Comedy', 'Musical'], 'tagsWithID': [1925, 9482, 651, 1932, 396, 528, 1554, 1685, 4121, 286, 34, 55, 4282, 1085, 71, 328, 5834, 210, 471, 605, 1759, 4961, 2786, 360, 369, 4082, 4857], 'tagsWithName': ['rock and roll']}
# ...
# {'movieID': '53769', 'genre': ['Comedy', 'Romance'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '53887', 'genre': ['Adventure', 'Drama', 'Fantasy'], 'tagsWithID': [6800, 93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '53921', 'genre': ['Drama', 'Thriller'], 'tagsWithID': [6717], 'tagsWithName': ['corvallis library']}
# {'movieID': '53953', 'genre': ['Drama', 'Horror', 'Thriller'], 'tagsWithID': [1061, 2566, 1802, 2712, 4413], 'tagsWithName': ['author:stephen king']}
# {'movieID': '53956', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [210, 2635, 16036, 2239], 'tagsWithName': ['bab cinema']}
# {'movieID': '54190', 'genre': ['Drama', 'Musical', 'Romance', 'War'], 'tagsWithID': [1759, 6717, 398, 871], 'tagsWithName': ['less than 300 ratings', 'rock and roll']}
# {'movieID': '54196', 'genre': ['Adventure', 'Fantasy', 'Mystery'], 'tagsWithID': [93, 2239], 'tagsWithName': ['nudity (topless)', 'netflix']}
# {'movieID': '54274', 'genre': ['Crime', 'Drama', 'Thriller'], 'tagsWithID': [54, 1023], 'tagsWithName': ['serial killer']}
# {'movieID': '54276', 'genre': ['Comedy', 'Drama', 'Romance'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '54278', 'genre': ['Action', 'Adventure', 'Children', 'Comedy', 'Fantasy', 'Sci-Fi'], 'tagsWithID': [2239, 6717, 583], 'tagsWithName': ['corvallis library']}
# {'movieID': '54331', 'genre': ['Comedy', 'Crime', 'Thriller'], 'tagsWithID': [4818], 'tagsWithName': ['opal']}
# {'movieID': '54372', 'genre': ['Crime', 'Drama', 'Mystery', 'Thriller'], 'tagsWithID': [1136, 2924], 'tagsWithName': ['toplist08', 'nudity (full frontal)']}
# {'movieID': '54510', 'genre': ['Drama', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '54648', 'genre': ['Action', 'Comedy', 'Crime', 'Thriller'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '54691', 'genre': ['Drama', 'Romance'], 'tagsWithID': [1224, 1061, 4279], 'tagsWithName': ['based on a book']}
# {'movieID': '54732', 'genre': ['Comedy'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '54745', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [1328, 1358, 398, 2239], 'tagsWithName': ['less than 300 ratings']}
# {'movieID': '54768', 'genre': ['Children', 'Comedy'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '54771', 'genre': ['Action', 'Drama', 'Horror', 'Sci-Fi', 'Thriller'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '54796', 'genre': ['Comedy', 'Drama', 'Romance'], 'tagsWithID': [5193, 93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '54958', 'genre': ['Crime', 'Drama', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '55063', 'genre': ['Documentary', 'Fantasy'], 'tagsWithID': [16036, 2924, 2239], 'tagsWithName': ['bab cinema', 'toplist08']}
# {'movieID': '55069', 'genre': ['Drama'], 'tagsWithID': [5764, 1413, 2925, 1136, 6715], 'tagsWithName': ['not corv lib']}
# {'movieID': '55080', 'genre': ['Crime', 'Drama', 'Thriller'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '55094', 'genre': ['Drama', 'Mystery'], 'tagsWithID': [2684, 93, 1023], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '55178', 'genre': ['Drama'], 'tagsWithID': [4818], 'tagsWithName': ['opal']}
# {'movieID': '55245', 'genre': ['Comedy', 'Romance'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '55255', 'genre': ['Drama', 'Romance'], 'tagsWithID': [1136], 'tagsWithName': ['nudity (full frontal)']}
# {'movieID': '55257', 'genre': ['Action', 'Comedy', 'Horror', 'Thriller'], 'tagsWithID': [93, 655], 'tagsWithName': ['nudity (topless)', 'video game adaptation']}
# {'movieID': '55272', 'genre': ['Crime', 'Drama'], 'tagsWithID': [69], 'tagsWithName': ['drugs']}
# {'movieID': '55274', 'genre': ['Drama'], 'tagsWithID': [4818], 'tagsWithName': ['opal']}
# {'movieID': '55286', 'genre': ['Drama', 'Romance'], 'tagsWithID': [625, 6715, 1401], 'tagsWithName': ['not corv lib']}
# {'movieID': '55498', 'genre': ['Adventure', 'Drama', 'Romance'], 'tagsWithID': [1136], 'tagsWithName': ['nudity (full frontal)']}
# {'movieID': '55726', 'genre': ['Drama'], 'tagsWithID': [16036, 2239], 'tagsWithName': ['bab cinema']}
# {'movieID': '55768', 'genre': ['Animation', 'Comedy'], 'tagsWithID': [2136, 1715, 6717], 'tagsWithName': ['corvallis library']}
# {'movieID': '56028', 'genre': ['Drama'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '56060', 'genre': ['Comedy', 'Drama', 'Romance', 'War'], 'tagsWithID': [4817, 93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '56145', 'genre': ['Drama', 'Horror', 'Sci-Fi', 'Thriller'], 'tagsWithID': [1224, 4755, 4413, 15437], 'tagsWithName': ['author:stephen king']}
# {'movieID': '56274', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '56607', 'genre': ['Drama'], 'tagsWithID': [6880, 1061, 1224, 587, 2925, 7186, 1364, 11092, 1368, 1023], 'tagsWithName': ['based on a book']}
# {'movieID': '56719', 'genre': ['Drama'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '56748', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '57243', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [4818], 'tagsWithName': ['opal']}
# {'movieID': '57326', 'genre': ['Action', 'Adventure', 'Fantasy'], 'tagsWithID': [715, 77, 655], 'tagsWithName': ['video game adaptation']}
# {'movieID': '57504', 'genre': ['Animation', 'Comedy', 'Drama', 'Romance', 'Sci-Fi'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '57526', 'genre': ['Crime', 'Thriller'], 'tagsWithID': [54], 'tagsWithName': ['serial killer']}
# {'movieID': '57550', 'genre': ['Drama'], 'tagsWithID': [9926], 'tagsWithName': ['svens to see list']}
# {'movieID': '57640', 'genre': ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi'], 'tagsWithID': [2693, 1023, 9068, 7408, 9810, 1940, 9334, 11449, 699, 1791], 'tagsWithName': ['based on a comic']}
# {'movieID': '57792', 'genre': ['Comedy'], 'tagsWithID': [4818], 'tagsWithName': ['opal']}
# {'movieID': '57910', 'genre': ['Comedy', 'Horror'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '58105', 'genre': ['Adventure', 'Children', 'Drama', 'Fantasy'], 'tagsWithID': [16036, 1061], 'tagsWithName': ['bab cinema']}
# {'movieID': '58154', 'genre': ['Drama', 'Romance'], 'tagsWithID': [2260, 1061, 10276], 'tagsWithName': ['based on a book']}
# {'movieID': '58191', 'genre': ['Documentary'], 'tagsWithID': [6548, 794, 6715, 2924], 'tagsWithName': ['not corv lib', 'toplist08']}
# {'movieID': '58297', 'genre': ['Action', 'Drama', 'Sci-Fi', 'Thriller'], 'tagsWithID': [5097, 6001], 'tagsWithName': ['unintentional comedy']}
# {'movieID': '58303', 'genre': ['Crime', 'Drama', 'War'], 'tagsWithID': [16036, 1061, 633, 93, 11321], 'tagsWithName': ['bab cinema']}
# {'movieID': '58306', 'genre': ['Drama', 'Romance', 'War'], 'tagsWithID': [4818, 16036], 'tagsWithName': ['bab cinema', 'opal']}
# {'movieID': '58309', 'genre': ['Documentary'], 'tagsWithID': [16036], 'tagsWithName': ['bab cinema']}
# {'movieID': '58332', 'genre': ['Fantasy', 'Horror', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '58334', 'genre': ['Drama', 'Romance'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '58347', 'genre': ['Children', 'Comedy', 'Fantasy', 'Romance'], 'tagsWithID': [4818], 'tagsWithName': ['opal']}
# {'movieID': '58351', 'genre': ['Drama'], 'tagsWithID': [16036, 2239], 'tagsWithName': ['bab cinema']}
# {'movieID': '58367', 'genre': ['Drama'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '58492', 'genre': ['Drama'], 'tagsWithID': [4818, 610], 'tagsWithName': ['opal']}
# {'movieID': '58706', 'genre': ['Adventure', 'Drama'], 'tagsWithID': [4818], 'tagsWithName': ['opal']}
# {'movieID': '58783', 'genre': ['Drama', 'Romance', 'Sci-Fi'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '58806', 'genre': ['Comedy', 'Drama', 'Romance'], 'tagsWithID': [4818, 1517], 'tagsWithName': ['opal']}
# {'movieID': '58839', 'genre': ['Comedy', 'Drama', 'Romance'], 'tagsWithID': [8929], 'tagsWithName': ['sport:american football']}
# {'movieID': '58879', 'genre': ['Documentary', 'IMAX', 'Musical'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '59022', 'genre': ['Adventure', 'Comedy'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '59026', 'genre': ['Comedy'], 'tagsWithID': [1176, 1061, 93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '59065', 'genre': ['Crime', 'Drama'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '59103', 'genre': ['Action', 'Adventure', 'Comedy', 'Fantasy'], 'tagsWithID': [5156], 'tagsWithName': ['kung fu']}
# {'movieID': '59105', 'genre': ['Documentary'], 'tagsWithID': [1136], 'tagsWithName': ['nudity (full frontal)']}
# {'movieID': '59256', 'genre': ['Action', 'Drama', 'Thriller'], 'tagsWithID': [93, 5543], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '59290', 'genre': ['Drama'], 'tagsWithID': [1136], 'tagsWithName': ['nudity (full frontal)']}
# {'movieID': '59336', 'genre': ['Action', 'Drama'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '59362', 'genre': ['Crime', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '59478', 'genre': ['Documentary'], 'tagsWithID': [16036], 'tagsWithName': ['bab cinema']}
# {'movieID': '59519', 'genre': ['Drama'], 'tagsWithID': [93, 2239], 'tagsWithName': ['nudity (topless)', 'netflix']}
# {'movieID': '59604', 'genre': ['Crime', 'Drama', 'Horror', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '59607', 'genre': ['Documentary'], 'tagsWithID': [5512], 'tagsWithName': ['food']}
# {'movieID': '59729', 'genre': ['Crime', 'Drama'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '59738', 'genre': ['Horror', 'Mystery', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '59834', 'genre': ['Adventure', 'Western'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '59915', 'genre': ['Horror', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '60044', 'genre': ['Comedy'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '60137', 'genre': ['Documentary'], 'tagsWithID': [16036], 'tagsWithName': ['bab cinema']}
# {'movieID': '60147', 'genre': ['Drama', 'Mystery'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '60295', 'genre': ['Documentary'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '60333', 'genre': ['Documentary'], 'tagsWithID': [7050, 2924], 'tagsWithName': ['toplist08']}
# {'movieID': '60363', 'genre': ['Comedy', 'Horror'], 'tagsWithID': [595, 93], 'tagsWithName': ['nudity (topless)', 'nudity (rear)']}
# {'movieID': '60393', 'genre': ['Drama'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '60411', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [1554], 'tagsWithName': ['criterion']}
# {'movieID': '60418', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [4818], 'tagsWithName': ['opal']}
# {'movieID': '60421', 'genre': ['Drama'], 'tagsWithID': [1224, 9809, 1061], 'tagsWithName': ['based on a book']}
# {'movieID': '60530', 'genre': ['Drama'], 'tagsWithID': [1136], 'tagsWithName': ['nudity (full frontal)']}
# {'movieID': '60566', 'genre': ['Crime', 'Drama', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '60688', 'genre': ['Action', 'Drama', 'Western'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '60745', 'genre': ['Crime', 'Drama', 'Thriller'], 'tagsWithID': [1554], 'tagsWithName': ['criterion']}
# {'movieID': '60753', 'genre': ['Action', 'Crime', 'Drama'], 'tagsWithID': [172, 93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '60763', 'genre': ['Documentary'], 'tagsWithID': [2239], 'tagsWithName': ['netflix']}
# {'movieID': '60832', 'genre': ['Crime', 'Horror', 'Thriller'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '60943', 'genre': ['Drama'], 'tagsWithID': [681, 692, 2924], 'tagsWithName': ['toplist08']}
# {'movieID': '61024', 'genre': ['Action', 'Comedy', 'Crime', 'Thriller'], 'tagsWithID': [1400, 11449, 2924, 6548], 'tagsWithName': ['toplist08']}
# {'movieID': '61073', 'genre': ['Action', 'Drama', 'Thriller'], 'tagsWithID': [1136, 2703], 'tagsWithName': ['nudity (full frontal)']}
# {'movieID': '61075', 'genre': ['Drama', 'Romance'], 'tagsWithID': [2924, 93], 'tagsWithName': ['nudity (topless)', 'toplist08']}
# {'movieID': '61236', 'genre': ['Animation', 'Documentary', 'War'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '61240', 'genre': ['Drama', 'Horror', 'Romance'], 'tagsWithID': [2924, 398, 753, 54, 62], 'tagsWithName': ['less than 300 ratings']}
# {'movieID': '61262', 'genre': ['Horror', 'Thriller'], 'tagsWithID': [11449, 93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '61279', 'genre': ['Drama'], 'tagsWithID': [1554], 'tagsWithName': ['criterion']}
# {'movieID': '61350', 'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'], 'tagsWithID': [1061, 366], 'tagsWithName': ['based on a book']}
# {'movieID': '61354', 'genre': ['Comedy'], 'tagsWithID': [595], 'tagsWithName': ['nudity (rear)']}
# {'movieID': '61357', 'genre': ['Documentary'], 'tagsWithID': [4817, 2924], 'tagsWithName': ['toplist08']}
# {'movieID': '61473', 'genre': ['Drama', 'War'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '61646', 'genre': ['Drama'], 'tagsWithID': [2136, 93, 4294], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '61729', 'genre': ['Comedy', 'Romance'], 'tagsWithID': [2924, 845], 'tagsWithName': ['toplist08']}
# {'movieID': '61970', 'genre': ['Sci-Fi'], 'tagsWithID': [93], 'tagsWithName': ['nudity (topless)']}
# {'movieID': '62049', 'genre': ['Drama', 'Sci-Fi'], 'tagsWithID': [1061, 1224, 2295, 24, 4381], 'tagsWithName': ['not available from netflix', 'based on a book']}
# {'movieID': '62250', 'genre': ['Crime', 'Drama'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '62394', 'genre': ['Action', 'Crime', 'Drama', 'Thriller'], 'tagsWithID': [1023, 7407, 2623], 'tagsWithName': ['adapted from:game']}
# {'movieID': '62511', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [4817, 2924, 2239], 'tagsWithName': ['toplist08']}
# {'movieID': '62801', 'genre': ['Action', 'Drama'], 'tagsWithID': [398], 'tagsWithName': ['less than 300 ratings']}
# {'movieID': '63062', 'genre': ['Crime', 'Drama', 'Mystery'], 'tagsWithID': [4817, 859, 2924], 'tagsWithName': ['toplist08']}
# {'movieID': '63121', 'genre': ['Drama', 'Romance'], 'tagsWithID': [1224, 1061, 8927], 'tagsWithName': ['author:charles dickens', 'based on a book']}
# {'movieID': '63446', 'genre': ['Comedy', 'Drama'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '63808', 'genre': ['Drama'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '63876', 'genre': ['Drama'], 'tagsWithID': [8993, 554, 2924, 689, 499, 9530, 603], 'tagsWithName': ['san francisco']}
# {'movieID': '64229', 'genre': ['Drama', 'Musical'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '64575', 'genre': ['Drama', 'Mystery'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '64620', 'genre': ['Drama'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '64622', 'genre': ['Drama', 'Romance', 'Thriller', 'War'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}
# {'movieID': '64701', 'genre': ['Drama', 'Mystery'], 'tagsWithID': [952, 2924], 'tagsWithName': ['toplist08']}
# {'movieID': '64993', 'genre': ['Animation', 'Drama', 'Romance'], 'tagsWithID': [712, 473, 740, 687], 'tagsWithName': ['anime']}
# {'movieID': '65006', 'genre': ['Mystery', 'Thriller'], 'tagsWithID': [595], 'tagsWithName': ['nudity (rear)']}
# {'movieID': '65130', 'genre': ['Drama', 'Romance'], 'tagsWithID': [2924], 'tagsWithName': ['toplist08']}

# %%
import csv

input_file_path = '/Users/abhishekjaiswal/Downloads/moreAccurate_data.csv'
output_file_path = '/Users/abhishekjaiswal/Downloads/filtered_data.csv'

data = []
with open(input_file_path, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # Convert string representation of lists to actual lists
        row['genre'] = eval(row['genre'])
        row['tagsWithID'] = eval(row['tagsWithID'])
        row['tagsWithName'] = eval(row['tagsWithName'])
        data.append(row)

# Filter out rows with empty values in tagsWithName
filtered_data = [row for row in data if row['tagsWithName']]

# Filtered data to a new CSV file
fieldnames = ['movieID', 'genre', 'tagsWithID', 'tagsWithName']
with open(output_file_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Write header
    writer.writeheader()
    
    # Write filtered rows
    for row in filtered_data:
        writer.writerow(row)

print("Filtered data saved to:", output_file_path)
# Out:
# Filtered data saved to: /Users/abhishekjaiswal/Downloads/filtered_data.csv
